# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"E:\AI & Data_Science\Data science files\07-Exploratory Data Analysis (EDA) with Numpy & Pandas\code\01-Pandas\data\Salaries.csv",index_col='Id')
df
# Out:
#              EmployeeName                                        JobTitle  \
# Id
# 1          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 3          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 4       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 5         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148650      Roy I Tillery                                       Custodian
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653       Not provided                                    Not provided
# 148654          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# Id
# ...

# %%
data = pd.read_csv(r"E:\AI & Data_Science\Data science files\07-Exploratory Data Analysis (EDA) with Numpy & Pandas\code\01-Pandas\data\spam_dataset.csv",sep = '\t', encoding = 'utf-8', names=['Status','Email'])
data
# Out:
#      Status                                              Email
# 0       ham                      Ok lar... Joking wif u oni...
# 1      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 2       ham  U dun say so early hor... U c already then say...
# 3       ham  Nah I don't think he goes to usf, he lives aro...
# 4      spam  FreeMsg Hey there darling it's been 3 week's n...
# ...     ...                                                ...
# 5566   spam  This is the 2nd time we have tried 2 contact u...
# 5567    ham               Will ü b going to esplanade fr home?
# 5568    ham  Pity, * was in mood for that. So...any other s...
# 5569    ham  The guy did some bitching but I acted like i'd...
# 5570    ham                         Rofl. Its true to its name
#
# [5571 rows x 2 columns]

# %%
dEx = pd.read_excel(r"E:\AI & Data_Science\Data science files\07-Exploratory Data Analysis (EDA) with Numpy & Pandas\code\01-Pandas\data\Excel_Sample.xlsx")
dEx
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
dEx.drop('Unnamed: 0',axis = 1, inplace = True)
dEx
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
import sqlite3

# %%
conn = sqlite3.connect(r"E:\AI & Data_Science\Data science files\07-Exploratory Data Analysis (EDA) with Numpy & Pandas\code\01-Pandas\data\test.db")

# %%
df_sql = pd.read_sql('SELECT * FROM data where City = ?',params = ['Chicago'],con = conn)
df_sql
# Out:
#     index                                          Bank Name     City  ST  \
# 0       6                Washington Federal Bank for Savings  Chicago  IL
# 1      12                      Seaway Bank and Trust Company  Chicago  IL
# 2      22                                     Edgebrook Bank  Chicago  IL
# 3      25                            Highland Community Bank  Chicago  IL
# 4      29              The National Republic Bank of Chicago  Chicago  IL
# 5      31                              GreenChoice Bank, fsb  Chicago  IL
# 6      66                                      Covenant Bank  Chicago  IL
# 7      82  Second Federal Savings and Loan Association of...  Chicago  IL
# 8     107                                      New City Bank  Chicago  IL
# 9     163                         First Chicago Bank & Trust  Chicago  IL
# 10    198                       Community First Bank Chicago  Chicago  IL
# 11    255                                          ShoreBank  Chicago  IL
# ...
