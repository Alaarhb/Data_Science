# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"E:\AI & Data_Science\Data science files\07-Exploratory Data Analysis (EDA) with Numpy & Pandas\code\01-Pandas\data\gapminder-FiveYearData.csv")
df
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
df.tail()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 1699  Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700  Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701  Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702  Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703  Zimbabwe  2007  12311143.0    Africa   43.487  469.709298

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   year       1704 non-null   int64
#  2   pop        1704 non-null   float64
#  3   continent  1704 non-null   object
#  4   lifeExp    1704 non-null   float64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 80.0+ KB

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 'NATHANIEL FORD',
#         'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY', ..., nan,
#         'San Francisco', nan],
#        [2, 'GARY JIMENEZ', 'CAPTAIN III (POLICE DEPARTMENT)', ..., nan,
#         'San Francisco', nan],
#        [3, 'ALBERT PARDINI', 'CAPTAIN III (POLICE DEPARTMENT)', ..., nan,
#         'San Francisco', nan],
#        ...,
#        [148652, 'Not provided', 'Not provided', ..., nan,
#         'San Francisco', nan],
#        [148653, 'Not provided', 'Not provided', ..., nan,
#         'San Francisco', nan],
#        [148654, 'Joe Lopez', 'Counselor, Log Cabin Ranch', ..., nan,
#         'San Francisco', nan]], dtype=object)

# %%
df.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status              float64
# dtype: object

# %%
df.head(2)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN

# %%
df.tail(2)
# Out:
#             Id  EmployeeName                    JobTitle  BasePay  \
# 148652  148653  Not provided                Not provided      NaN
# 148653  148654     Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148652          NaN       NaN       NaN      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency  Status
# 148652    NaN  San Francisco     NaN
# 148653    NaN  San Francisco     NaN

# %%
df.drop(['Id','EmployeeName','Notes','Status'],axis = 1, inplace = True)

# %%
df
# Out:
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# 148650                                    Not provided        NaN
# 148651                                    Not provided        NaN
# 148652                                    Not provided        NaN
# 148653                      Counselor, Log Cabin Ranch       0.00
#
#         OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# 0              0.00  400184.25       NaN  567595.43         567595.43  2011
# ...

# %%
df.head()
# Out:
#                                          JobTitle    BasePay  OvertimePay  \
# 0  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                 CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                 CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3            WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
#
#     OtherPay  Benefits   TotalPay  TotalPayBenefits  Year         Agency
# 0  400184.25       NaN  567595.43         567595.43  2011  San Francisco
# 1  137811.38       NaN  538909.28         538909.28  2011  San Francisco
# 2   16452.60       NaN  335279.91         335279.91  2011  San Francisco
# 3  198306.90       NaN  332343.61         332343.61  2011  San Francisco
# 4  182234.59       NaN  326373.19         326373.19  2011  San Francisco

# %%
#df['BasePay'].mean()
# df['BasePay'].median()
# df['BasePay'].min()
# df['BasePay'].max()
# df['BasePay'].sum()
# df['BasePay'].std()
# df['BasePay'].count()
df['BasePay'].quantile(0.75)
# Out:
# 94691.05

# %%
q1 = df['BasePay'].quantile(0.25)
q3 = df['BasePay'].quantile(0.75)
iqr = q3 - q1 
iqr
# Out:
# 61102.850000000006

# %%
wisk_min = q1 - 1.5 * iqr 
wisk_max = q3 + 1.5 * iqr
df[   (df['BasePay'] < wisk_min) | (df['BasePay'] > wisk_max)   ]
# Out:
#                                                 JobTitle    BasePay  \
# 2                        CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 7                         DEPUTY DIRECTOR OF INVESTMENTS  256576.96
# 9                 CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  285262.00
# 10      ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  194999.39
# 12                           EXECUTIVE CONTRACT EMPLOYEE  294580.02
# ...                                                  ...        ...
# 111314                       Senior Physician Specialist  187076.75
# 111317                                          Engineer  188189.15
# 111368                       Head Atty, Civil & Criminal  191709.01
# 111403                                 Deputy Dir I, MTA  186851.70
# 111625                       Head Atty, Civil & Criminal  190176.04
#
#         OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# ...

# %%
df['BasePay'].describe()
# Out:
# count    148045.000000
# mean      66325.448840
# std       42764.635495
# min        -166.010000
# 25%       33588.200000
# 50%       65007.450000
# 75%       94691.050000
# max      319275.010000
# Name: BasePay, dtype: float64

# %%
df.describe()
# Out:
#              BasePay    OvertimePay       OtherPay       Benefits  \
# count  148045.000000  148650.000000  148650.000000  112491.000000
# mean    66325.448840    5066.059886    3648.767297   25007.893151
# std     42764.635495   11454.380559    8056.601866   15402.215858
# min      -166.010000      -0.010000   -7058.590000     -33.890000
# 25%     33588.200000       0.000000       0.000000   11535.395000
# 50%     65007.450000       0.000000     811.270000   28628.620000
# 75%     94691.050000    4658.175000    4236.065000   35566.855000
# max    319275.010000  245131.880000  400184.250000   96570.660000
#
#             TotalPay  TotalPayBenefits           Year
# count  148654.000000     148654.000000  148654.000000
# mean    74768.321972      93692.554811    2012.522643
# std     50517.005274      62793.533483       1.117538
# min      -618.130000       -618.130000    2011.000000
# 25%     36168.995000      44065.650000    2012.000000
# ...

# %%
df['Agency'].unique()
# Out:
# array(['San Francisco'], dtype=object)

# %%
df['Year'].unique()
# Out:
# array([2011, 2012, 2013, 2014], dtype=int64)

# %%
df['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %%
len(df['JobTitle'].unique())
# Out:
# 2159

# %%
df['Agency'].value_counts()
# Out:
# Agency
# San Francisco    148654
# Name: count, dtype: int64

# %%
df['Year'].value_counts()
# Out:
# Year
# 2014    38123
# 2013    37606
# 2012    36766
# 2011    36159
# Name: count, dtype: int64

# %%
df['JobTitle'].value_counts()
# Out:
# JobTitle
# Transit Operator                                  7036
# Special Nurse                                     4389
# Registered Nurse                                  3736
# Public Svc Aide-Public Works                      2518
# Police Officer 3                                  2421
#                                                   ...
# CHIEF HOUSING INSPECTOR                              1
# TRAFFIC SIGNAL OPERATOR                              1
# COURT COMPUTER FACILITIES COORDINATOR                1
# AUTOMOTIVE BODY AND FENDER WORKER SUPERVISOR I       1
# VICTIM & WITNESS TECHNICIAN                          1
# Name: count, Length: 2159, dtype: int64

# %%
df['JobTitle'].value_counts().head(20)
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Custodian                       2418
# TRANSIT OPERATOR                2388
# Firefighter                     2359
# Recreation Leader               1971
# Patient Care Assistant          1945
# Deputy Sheriff                  1933
# Police Officer                  1476
# SPECIAL NURSE                   1402
# Public Service Trainee          1328
# REGISTERED NURSE                1219
# Police Officer 2                1141
# Attorney (Civil/Criminal)       1126
# Porter                          1095
# Sergeant 3                      1047
# General Laborer                 1033
# Name: count, dtype: int64

# %%
df['JobTitle'].mode()[0]
# Out:
# 'Transit Operator'

# %%
df['Year'].mode()[0]
# Out:
# 2014

# %%
df['Agency'].mode()[0]
# Out:
# 'San Francisco'

# %%
df.sort_values(by = 'BasePay',ascending=False)
# Out:
#                             JobTitle    BasePay  OvertimePay  OtherPay  \
# 72925                Chief of Police  319275.01         0.00  20007.06
# 110532             Asst Med Examiner  318835.49     10712.95  60563.54
# 72929   Dep Dir for Investments, Ret  315572.01         0.00      0.00
# 72926         Chief, Fire Department  313686.01         0.00  23236.00
# 72931    Executive Contract Employee  313312.52         0.00      0.00
# ...                              ...        ...          ...       ...
# 110530              Police Officer 3        NaN         0.00      0.00
# 148646                  Not provided        NaN          NaN       NaN
# 148650                  Not provided        NaN          NaN       NaN
# 148651                  Not provided        NaN          NaN       NaN
# 148652                  Not provided        NaN          NaN       NaN
#
#         Benefits   TotalPay  TotalPayBenefits  Year         Agency
# ...

# %%
new_df = df[df['Year'].isin([2011,2014])]
new_df
# Out:
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# 148650                                    Not provided        NaN
# 148651                                    Not provided        NaN
# 148652                                    Not provided        NaN
# 148653                      Counselor, Log Cabin Ranch       0.00
#
#         OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# 0              0.00  400184.25       NaN  567595.43         567595.43  2011
# ...

# %%
new_df.describe()
# Out:
#              BasePay    OvertimePay       OtherPay      Benefits  \
# count   74278.000000   74278.000000   74278.000000  38119.000000
# mean    65119.354197    4978.020330    3559.778373  24789.601756
# std     42413.147668   11178.652263    7861.693858  15703.733930
# min         0.000000       0.000000    -618.130000    -13.800000
# 25%     31849.415000       0.000000       0.000000  10269.975000
# 50%     64089.010000       0.000000     749.695000  28426.980000
# 75%     94102.957500    4613.180000    4076.505000  35445.100000
# max    318835.490000  245131.880000  400184.250000  96570.660000
#
#             TotalPay  TotalPayBenefits          Year
# count   74282.000000      74282.000000  74282.000000
# mean    73653.186548      86374.368386   2012.539660
# std     49732.489830      59607.130675      1.499486
# min      -618.130000       -618.130000   2011.000000
# 25%     35193.415000      39967.025000   2011.000000
# 50%     70255.900000      83877.005000   2014.000000
# ...

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df.corr()
#
# File d:\programs\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File d:\programs\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
import seaborn as sns

# %%
sns.countplot(x='Year',data = df)
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %%
sns.pairplot(new_df)
